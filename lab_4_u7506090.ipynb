# %% [markdown]
# <a href="https://colab.research.google.com/github/RubberSoul-l/AETA/blob/main/lab_4_u7506090.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # lab 4
# u7506090
# Bodan Liu

# %% [markdown]
# # Basic setup in google colab

# %%
# !git clone https://github.com/RubberSoul-l/444
# Out:
# Cloning into '444'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 109 (delta 10), reused 0 (delta 0), pack-reused 84
# Receiving objects: 100% (109/109), 23.97 MiB | 12.91 MiB/s, done.
# Resolving deltas: 100% (41/41), done.

# %%
# !unzip drive/MyDrive/cifar-10-cam-seg-data\ 2.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: cifar-10-cam-seg-data/train/auto_s_002360.png
#   inflating: __MACOSX/cifar-10-cam-seg-data/train/._auto_s_002360.png
#   inflating: cifar-10-cam-seg-data/train/stud_mare_s_000267.png
#   inflating: __MACOSX/cifar-10-cam-seg-data/train/._stud_mare_s_000267.png
#   inflating: cifar-10-cam-seg-data/train/pekinese_s_001892.png
#   inflating: __MACOSX/cifar-10-cam-seg-data/train/._pekinese_s_001892.png
#   inflating: cifar-10-cam-seg-data/train/stud_mare_s_001179.png
#   inflating: __MACOSX/cifar-10-cam-seg-data/train/._stud_mare_s_001179.png
#   inflating: cifar-10-cam-seg-data/train/honey_eater_s_000921.png
#   inflating: __MACOSX/cifar-10-cam-seg-data/train/._honey_eater_s_000921.png
#   inflating: cifar-10-cam-seg-data/train/tabby_cat_s_002440.png
#   inflating: __MACOSX/cifar-10-cam-seg-data/train/._tabby_cat_s_002440.png
#   inflating: cifar-10-cam-seg-data/train/cat_s_002075.png
# ...

# %%
import os
os.chdir('444/lab4')

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
import torch
import torch.nn as nn
import numpy as np
from torchvision.models import resnet18
model = resnet18(pretrained=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
model

# %% [markdown]
# # 2.1 - 2.2.1 CAM with test evaluation

# %%
# !python main.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# <class 'torch.utils.data.dataloader.DataLoader'>
# Network training starts ...
# epoch:0, iter:100, time:16.99, loss:1.94583
# epoch:0, iter:200, time:14.80, loss:1.98191
# epoch:0, iter:300, time:14.86, loss:1.67419
# epoch:0, iter:400, time:14.77, loss:1.67821
# ...

# %% [markdown]
# # 2.2.2 CAM with cross validation

# %%
# !python main.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Fold:1
# <class 'torch.utils.data.dataloader.DataLoader'>
# Network training starts ...
# epoch:0, iter:100, time:21.73, loss:1.95924
# epoch:0, iter:200, time:19.40, loss:1.82029
# epoch:0, iter:300, time:19.94, loss:1.71905
# epoch:0, iter:400, time:19.35, loss:1.63889
# ...

# %% [markdown]
# # 3.1-3.3 SEG mode

# %%
# !python main.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# <class 'torch.utils.data.dataloader.DataLoader'>
# Network training starts ...
# epoch:0, iter:100, time:26.13, loss:1.93851
# epoch:0, iter:200, time:18.54, loss:1.95231
# epoch:0, iter:300, time:18.62, loss:1.63708
# epoch:0, iter:400, time:18.69, loss:1.62151
# ...

# %% [markdown]
# # 3.4 Visualization and IoU

# %%
# !python visualize.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Resume completed for the model
#
# SEG vis done
# SEG vis done
# SEG vis done
# SEG vis done
# SEG vis done
# SEG vis done
# SEG vis done
# SEG vis done
# SEG vis done
# SEG vis done

# %% [markdown]
# ## 3.4.2
# Intersection over Union (IoU) is a metric to assess how much overlaaping is between two pictures, for segmentation task, IoU can evaluate the overlap of ground truth (GT) and predicted region (PR).
# <br>
# $$IoU = \frac{GT\cap PR}{GT \cup PR}$$

# %%
# !python iou.py
# Out:
# Class: plane | CAM IoU: 0.185 | SEG IoU: 0.404
# Class: car | CAM IoU: 0.151 | SEG IoU: 0.226
# Class: bird | CAM IoU: 0.330 | SEG IoU: 0.608
# Class: cat | CAM IoU: 0.092 | SEG IoU: 0.132
# Class: deer | CAM IoU: 0.455 | SEG IoU: 0.639
# Class: dog | CAM IoU: 0.313 | SEG IoU: 0.643
# Class: frog | CAM IoU: 0.163 | SEG IoU: 0.282
# Class: horse | CAM IoU: 0.220 | SEG IoU: 0.385
# Class: ship | CAM IoU: 0.176 | SEG IoU: 0.611
# Class: truck | CAM IoU: 0.108 | SEG IoU: 0.172

# %% [markdown]
# ### download visualization images from colab

# %%
# !zip -r /content/lab4.zip /content/444/lab4/visualize
# Out:
# updating: content/444/lab4/visualize/ (stored 0%)
# updating: content/444/lab4/visualize/SEG/ (stored 0%)
# updating: content/444/lab4/visualize/SEG/truck_seg.png (deflated 20%)
# updating: content/444/lab4/visualize/SEG/plane_seg.png (deflated 22%)
# updating: content/444/lab4/visualize/SEG/truck.png (deflated 4%)
# updating: content/444/lab4/visualize/SEG/frog.png (deflated 3%)
# updating: content/444/lab4/visualize/SEG/ship.png (deflated 4%)
# updating: content/444/lab4/visualize/SEG/car.png (deflated 6%)
# updating: content/444/lab4/visualize/SEG/cat_seg.png (deflated 17%)
# updating: content/444/lab4/visualize/SEG/cat.png (deflated 5%)
# updating: content/444/lab4/visualize/SEG/deer_seg.png (deflated 34%)
# updating: content/444/lab4/visualize/SEG/horse.png (deflated 5%)
# updating: content/444/lab4/visualize/SEG/bird_seg.png (deflated 11%)
# updating: content/444/lab4/visualize/SEG/frog_seg.png (deflated 9%)
# updating: content/444/lab4/visualize/SEG/bird.png (deflated 5%)
# ...
